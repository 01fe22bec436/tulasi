# %% [markdown]
# **ASSIGEMENT**

# %% [markdown]
# ADD

# %%
a=55
b=10
sum=a+b
print(sum)
# Out:
# 65

# %% [markdown]
# SUB

# %%
a=9999
b=1111
c=0000
sub=a-b-c
print(sub)
# Out:
# 8888

# %% [markdown]
# DIV

# %%
a=2000
b=10
div=a/b
print(div)
# Out:
# 200.0

# %% [markdown]
# MUL

# %%
a=55555
b=22222
mul=a*b
print(mul)
# Out:
# 1234543210

# %% [markdown]
# SQUAREING

# %%
a=25
square=a**2
print(square)
# Out:
# 625

# %% [markdown]
# QUESTIENT

# %%
a=625
b=5
questient=a//b
print(questient)
# Out:
# 125

# %% [markdown]
# REMINDER

# %%
a=625
b=5
reminder=a%b
print(reminder)
# Out:
# 0

# %% [markdown]
# SQUARE ROOT

# %%
import math
a=625
math.sqrt(a)
# Out:
# 25.0

# %% [markdown]
# OPERATION

# %%
a=45
b=5
c=5
d=2
operation=a+b-c*d
print(operation)
# Out:
# 40
