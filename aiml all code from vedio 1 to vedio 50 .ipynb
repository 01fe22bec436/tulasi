# %% [markdown]
# DATA **TYPES**

# %% [markdown]
# 1) Text

# %%
name="tulasi"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# 2 )**numeric**

# %%
num1=69
num2=56.89
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# sequences

# %% [markdown]
# **list**

# %%
list=['abc','123','30.45']
type(list)
# Out:
# list

# %%
print(list)
# Out:
# ['abc', '123', '30.45']

# %%
list2=['apple','200','India','apple']
print(len(list))
print(len(list2))
list3=list+list2
print(list3)
print(list)
print(len(list3))
# Out:
# 3
# 4
# ['abc', '123', '30.45', 'apple', '200', 'India', 'apple']
# ['abc', '123', '30.45']
# 7

# %%
list2.append('hubli')
list2
# Out:
# ['apple', '200', 'India', 'apple', 'hubli']

# %%
list2.clear()

# %%
lis=['kk','aa','kle','eee']
lis[0]
# Out:
# 'kk'

# %%
lis[2]
# Out:
# 'kle'

# %%
lis.sort()

# %%
lis
# Out:
# ['aa', 'eee', 'kk', 'kle']

# %% [markdown]
# **tuples**

# %%
tuple1=("hubli","belgum","hubli")
print(type(tuple1))
tuple2=("hubli")
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1=("hubli","belgum","hubli")
print(type(tuple1))
tuple2=("hubli",)
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple1=("hubli","belgum","hubli")
print(type(tuple1))
tuple2=("hubli",)
print(type(tuple2))
tuple3=(1,2,3,4,5)
print(type(tuple3))
tuple4=("asdf","123","1,2,3,4","true")
print(type(tuple4))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# Positive indexing

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
# Out:
# hubli
# belgum
# hubli

# %% [markdown]
# Negative indexing

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
# Out:
# hubli
# belgum
# hubli
# hubli

# %% [markdown]
# Joining of 2 tuples

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
tuple6=tuple1+tuple1
print(tuple6)
# Out:
# hubli
# belgum
# hubli
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')

# %% [markdown]
# Mulitiplication of tuples

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)
# Out:
# hubli
# belgum
# hubli
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)
y=tuple7.index('hubli')
print(y)
# Out:
# hubli
# belgum
# hubli
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')
# 0

# %%
tuple1=("hubli","belgum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)
y=tuple7.index('hubli')
print(y)
x=tuple7.count('hubli')
print(x)
# Out:
# hubli
# belgum
# hubli
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')
# ('hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli', 'hubli', 'belgum', 'hubli')
# 0
# 8

# %% [markdown]
# SETS

# %% [markdown]
# Creation of sets

# %%
set1={"red","blue","black"}
print(set1)
# Out:
# {'black', 'red', 'blue'}

# %% [markdown]
# Add element

# %%
set1={"red","blue","black"}
print(set1)
set1.add('orange')
print(set1)
# Out:
# {'black', 'red', 'blue'}
# {'black', 'orange', 'red', 'blue'}

# %% [markdown]
# Add 2 sets

# %%
set1={"red","blue","black"}
print(set1)
set1.add('orange')
print(set1)
set2={"ball","bat","wicket"}
set1.update(set2)
print(set1)
# Out:
# {'black', 'red', 'blue'}
# {'black', 'orange', 'red', 'blue'}
# {'black', 'wicket', 'orange', 'bat', 'ball', 'red', 'blue'}

# %% [markdown]
# DICTIONARY

# %% [markdown]
# Creation of dictionary

# %%
dict1={"name":"tulasi",
"age":"20",
"gender":"female"}
print(dict1)
# Out:
# {'name': 'tulasi', 'age': '20', 'gender': 'female'}

# %%
dict1={"name":"tulasi",
"age":"20",
"gender":"female"}
print(type(dict1))
# Out:
# <class 'dict'>

# %% [markdown]
# IF_ELSE CONDITION STATEMENTS

# %%
a=input("enter the value of a")
b=input("enter the value of b")
print(a)
print(b)
# Out:
# enter the value of a1
# enter the value of b5
# 1
# 5

# %%
if a>b:
print("the value of a is greater than b")
if a==b:
print("both a and b are same")
else a<b:
print("the value of b is greater than a")
# Out:
#   File "<ipython-input-13-30fcc2e3ec9b>", line 2
#     print("the value of a is greater than b")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
ball1_colour="green"
ball2_colour="blue"
ball3_colour="red"
ball4_colour="white"

pick_ball=input("please pick a ball")

if :
pick_ball==ball1_colour:
print("green ball is picked")
elif pick_ball==ball2_colour:
print("blue ball is picked")
if pick_ball==ball3_colour:
print("red ball is picked")
else:
print("white ball is picked")
# Out:
#   File "<ipython-input-17-be63f36f4925>", line 8
#     if :
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# OPERATORS

# %% [markdown]
# Arthmetic **operators**

# %%
x=12
y=4
sum=x+y
diff=x-y
prod=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y
print(sum,diff,prod,div,fdiv,mod,power)
# Out:
# 16 8 48 3.0 3 0 20736

# %%
age=input("enter the age")
print(type(age))
# Out:
# enter the age13
# <class 'str'>

# %%
age=int(input("enter the age"))
print(type(age))

# %%
age=int(input("enter the age"))
print(age>18 & age<60)
# Out:
# enter the age28
# True

# %%
age=int(input("enter the age"))
print(age>18 and age<60)
print(age>18 or age<21)
# Out:
# enter the age12
# False
# True

# %% [markdown]
# **4**)**BITWISE** **OPERATORS**

# %%
print(8&12)
print(0xF & 0xE)
# Out:
# 8
# 14

# %%
print(8|12)
print(0xF | 0xE)
# Out:
# 12
# 15

# %%
print(8 ^ 12)
print(0xF ^ 0xE)
# Out:
# 4
# 1

# %% [markdown]
# 5) **ASSIGNIMENT** **OPERATORS**

# %%
a=8
print(a)
a+=3
print(a)
# Out:
# 8
# 11

# %%
a=8
print(a)
a+=3
print(a)
a-=6
print(a)
a*=6
print(a)
# Out:
# 8
# 11
# 5
# 30

# %%
a=8
a//=2
print(a)
# Out:
# 4

# %%
a=8
a/=2
print(a)
# Out:
# 4.0

# %%
a=8
a%=2
print(a)
# Out:
# 0

# %%
a=8
a**=2
print(a)
# Out:
# 64

# %%
a=8
a&=2
print(a)
# Out:
# 0

# %%
a=8
a|=2
print(a)
# Out:
# 10

# %% [markdown]
# **IDENTITY** AND **MEMBERSHIP** **OPERATORS**

# %%
x=["Hubli","Belgaum"]
y=["Hubli","Belgaum"]
z=x
print(z is x)
print(y is x)
# Out:
# True
# False

# %%
x=["Hubli","Belgaum"]
y=["Hubli","Belgaum"]
z=x
z=y
print(z is x)
print(y is x)
print(y is z)
# Out:
# False
# False
# True

# %%
x=["Hubli","Belgaum"]
y=["Hubli","Belgaum"]
z=x
z=y
print(z is not x)
print(y is x)
print(y is z)
print("Hubli" in x)
# Out:
# True
# False
# True
# True

# %% [markdown]
# WHILE **LOOP**

# %%
num=int(input("enter the number"))
while num<=9:
print("number is single digit")
break
while("number is double digit")
break
else:
print("number has more than two digits")
# Out:
#   File "<ipython-input-1-22e48d7a1916>", line 3
#     print("number is single digit")
#     ^
# IndentationError: expected an indented block after 'while' statement on line 2

# %% [markdown]
# FOR **LOOP**

# %%
for x in range(1,6):
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(5,9):
print("single digit number")
for x in range(0,99,10):
print("double digit number")
# Out:
#   File "<ipython-input-3-e207601ad0e9>", line 2
#     print("single digit number")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %% [markdown]
# **FUNCTIONS**

# %%
def cake_baker():
  print("I am ready to bake the cake")

cake_baker()
# Out:
# I am ready to bake the cake

# %%
def cake_baker(p,f,s):
  print("No of pieces=",p)
  print("Falvor is=",f)
  print("Size is=",s)

cake_baker("5","choclate","2kg")
# Out:
# No of pieces= 5
# Falvor is= choclate
# Size is= 2kg

# %%
def cake_baker(p,f,s):
  print("No of pieces=",p)
  print("Falvor is=",f)
  print("Size is=",s)

cake_baker("5","choclate","2kg")
cake_baker("10","vanilla","5kg")
# Out:
# No of pieces= 5
# Falvor is= choclate
# Size is= 2kg
# No of pieces= 10
# Falvor is= vanilla
# Size is= 5kg

# %%
def add (*args):
  sum=0
  for i in args:
     sum+= i
  return sum
print(add(1,2,3))
# Out:
# 6

# %%
def add (*bunch):
  sum=0
  for i in bunch:
    sum+= i
  return sum
print(add(1,2,3,4,5,6))
# Out:
# 21

# %%
def greet(**kwargs):
  print("hello")
  for key,value in kwargs.item():
     print(value,end =" ")

greet(name="tulasi", usn="o1fe22bec436", branch="ece")
# Out:
#   File "<ipython-input-36-c7975970ca3c>", line 1
#     def greet(**kwargs)
#                        ^
# SyntaxError: expected ':'

# %%
import random
x=random.randint(1,9)
print(x)
# Out:
# 7

# %% [markdown]
# LOTTERY GAME SYSTEM

# %%
import random

computer=random.randint(1,9)
userinput=int(input("enter the number between 1 and 9"))
print(computer)
print(userinput)

if computer>userinput:
  print("computer won")
elif computer==userinput:
  print("TIE")
else:
  print("you won")
# Out:
# enter the number between 1 and 98
# 9
# 8
# computer won

# %% [markdown]
# GAME 2 ROCK PAPER SCISSORS

# %%
import random
gamelist=['rock','paper','scissors']
comp=random.choice(gamelist)
user=input("enter either rock or paper or scissors")
print(comp)
print(user)

if(comp=="rock" and user=="paper"):
  print("computer won")

elif(comp=="paper" and user=="scissors"):
  print("you won")
elif(comp=="scissors" and user=="paper"):
  print("computer won")
else:
  print("TIE")
# Out:
# rock
# scissors
# TIE

# %% [markdown]
# NUMPY=**np**

# %%
import numpy as np
a=np.array([35,1,34,36,27,48])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
b=np.zeros(3)
c=np.ones(4)
print(b)
print(c)
# Out:
# [0. 0. 0.]
# [1. 1. 1. 1.]

# %%
a=np.array([34,89,67,12,9])
d=np.sort(a)
print(d)
# Out:
# [ 9 12 34 67 89]

# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# GRAPH=MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,10)
m=0.6
c=25
y=m*x+c
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,10)
m=-25
c=250
y=m*x+c
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,10)
y=np.sin(x)
fig,a=plt.subplot()
a=plot(x,y,linewidth=3.0)
a.set(xlim=(0,9),xticks=np.arrange(1,9),ylim=(0,9),yticks=np.arrange(1,9))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-babd178a6664> in <cell line: 5>()
#       3 x=np.linspace(0,1,10)
#       4 y=np.sin(x)
# ----> 5 fig,a=plt.subplot()
#       6 a=plot(x,y,linewidth=3.0)
#       7 a.set(xlim=(0,9),xticks=np.arrange(1,9),ylim=(0,9),yticks=np.arrange(1,9))
#
# TypeError: cannot unpack non-iterable Axes object

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=4+2*np.sin(2*x)
fig,a=plot.subplot()
a=plt(x,y,linewidth=3.0)
a.set(xlim=(0,8),xticks=np.arrange(1,8),
      ylim=(0,8),yticks=np.arrange(1,8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b196a918171d> in <cell line: 5>()
#       3 x=np.linspace(0,10,100)
#       4 y=4+2*np.sin(2*x)
# ----> 5 fig,a=plot.subplot()
#       6 a=plt(x,y,linewidth=3.0)
#       7 a.set(xlim=(0,8),xticks=np.arrange(1,8),
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])

plt.scatter(Temp,Res)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])

plt.plot(Temp,Res)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])

plt.plot(Res,marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])

plt.plot(Res,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.title("Themistor characteristics")
plt.xlabel("Temp")
plt.ylabel("Res")

plt.plot(Temp,Res)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["Karnataka", "AP", "TN" ,"TG"])
y=np.array([65,68,89,86])

plt.bar(x,y)
plt.show()

plt.pie(y)
plt.show()
